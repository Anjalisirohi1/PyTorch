# %%
import torch

# %%
a =  torch.tensor(3.0,requires_grad = True)

# %%
b = a**2

# %%
a
# Out:
# tensor(3., requires_grad=True)

# %%
b
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
#b.backward()

# %%
#a.grad

# %%
c = torch.sin(b)

# %%
a
# Out:
# tensor(3., requires_grad=True)

# %%
b
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
c
# Out:
# tensor(0.4121, grad_fn=<SinBackward0>)

# %%
c.backward()

# %%
a.grad
# Out:
# tensor(-5.4668)

# %%
x = torch.tensor(6.7)
y = torch.tensor(0.0)

w = torch.tensor(1.0)
b = torch.tensor(0.0)

# %%
def binary_cross_entropy(prediction,target):
    epsilon = 1e-8 #to prevent log(0)
    prediction = torch.clamp(prediction,epsilon,1 - epsilon)
    return -(target * torch.log(prediction) + (1 - target) * torch.log(1 - prediction))

# %%
z = w*x + b
y_pred  = torch.sigmoid(z)

loss = binary_cross_entropy(y_pred,y)

# %%
loss
# Out:
# tensor(6.7012)

# %%
dloss_dy_pred = (y_pred - y)/(y_pred*(1-y_pred))

dy_pred_dz = y_pred * (1 - y_pred)

dz_dw = x
dz_db = 1

dL_dw = dloss_dy_pred * dy_pred_dz * dz_dw
dL_db = dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"Manual gradient of loss w.r.t weight(dw):{(dL_dw)}")
print(f"Manual gradient of loss w.r.t bias(db): {dL_db}")
# Out:
# Manual gradient of loss w.r.t weight(dw):6.691762447357178
# Manual gradient of loss w.r.t bias(db): 0.998770534992218

# %%
x = torch.tensor(6.7)
y = torch.tensor(0.0)

w = torch.tensor(1.0,requires_grad=True)
b = torch.tensor(0.0,requires_grad = True)

# %%
w
# Out:
# tensor(1., requires_grad=True)

# %%
b
# Out:
# tensor(0., requires_grad=True)

# %%
z = w*x + b
z
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)

# %%
y_pred = torch.sigmoid(z)

# %%
y_pred
# Out:
# tensor(0.9988, grad_fn=<SigmoidBackward0>)

# %%
loss = binary_cross_entropy(y_pred,y)
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
w.grad
# Out:
# tensor(6.6918)

# %%
b.grad
# Out:
# tensor(0.9988)

# %%
m = torch.tensor([1.0,2.0,3.0],requires_grad=True)

# %%
m
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
n = (m**2).mean()

# %%
n
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
n.backward()

# %%
m.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %%
# clearing grad
x = torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad # accumulating gradients
# Out:
# tensor(4.)

# %%
x.grad.zero_()
# Out:
# tensor(0.)

# %%
#disable gradient tracking
# during prediction we dont need backward propagation
x = torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()#it occupies memory

# %%
x.grad
# Out:
# tensor(4.)

# %% [markdown]
# option 1

# %%
x.requires_grad_(False)
# Out:
# tensor(2.)

# %%
x
# Out:
# tensor(2.)

# %%
y = x**2
y
# Out:
# tensor(4.)

# %%
#y.backward() wont be able to do this
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 y.backward()
#
# File c:\Users\anjal\.conda\envs\pytorch_env\lib\site-packages\torch\_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File c:\Users\anjal\.conda\envs\pytorch_env\lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
# ...

# %% [markdown]
# option 2

# %%
x = torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
z = x.detach()
z#this tensor will have exact same values as x but it now detached from computational graph
# Out:
# tensor(2.)

# %%
y = x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y1 = z**2
y1
# Out:
# tensor(4.)

# %%
y.backward()

# %%
#y1.backward()  wont be able to do this
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 y1.backward()
#
# File c:\Users\anjal\.conda\envs\pytorch_env\lib\site-packages\torch\_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File c:\Users\anjal\.conda\envs\pytorch_env\lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
# ...

# %% [markdown]
# option 3

# %%
x = torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
with torch.no_grad():
    y = x**2

# %%
y
# Out:
# tensor(4.)

# %%
#y.backward()  wont work
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 y.backward()
#
# File c:\Users\anjal\.conda\envs\pytorch_env\lib\site-packages\torch\_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File c:\Users\anjal\.conda\envs\pytorch_env\lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
# ...
